# %%
s = 'ABCD_GF782'

# %%
s[2:0]
# Out:
# ''

# %%
s[2:0:-1]   ## Python doesn't automatically reverse, you have to give explicit step
# Out:
# 'CB'

# %%
s[1] = 5
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s[1] = 5
#       2 s
#
# TypeError: 'str' object does not support item assignment

# %%
s = '5621sf'
s
# Out:
# '5621sf'

# %%
x = input("x")

print(x*5)
# Out:
# oh okay     oh okay     oh okay     oh okay     oh okay

# %%
x = 1

while x <= 5:
    print('oi', x)
    x = x+1
# Out:
# oi 1
# oi 2
# oi 3
# oi 4
# oi 5

# %%
while True:
    print('hey')
# Out:
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# ...

# %%
where = input("Left or right?")
x = 0

while where == 'right':
    where = input("Left or right?")
    x = x + 1
    if x == 2:
        print("sad")


print("you got out, yayy!!")
# Out:
# sad
# you got out, yayy!!

# %%
mysum = 0

for i in range(10):
    print("i is ", i)
    mysum += i
    print("mysum becomes " , mysum)
# Out:
# i is  0
# mysum becomes  0
# i is  1
# mysum becomes  1
# i is  2
# mysum becomes  3
# i is  3
# mysum becomes  6
# i is  4
# mysum becomes  10
# i is  5
# mysum becomes  15
# i is  6
# mysum becomes  21
# i is  7
# mysum becomes  28
# i is  8
# mysum becomes  36
# i is  9
# mysum becomes  45
