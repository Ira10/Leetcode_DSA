# %%
arr = [3,4,5,62,24,123,234,345,244,2311,23333,33323,3,4,4,56,32,234,4,45,3,32,344,2333333,98,906,566]
target = 56

# %%
arr
# Out:
# [3,
#  4,
#  5,
#  62,
#  24,
#  123,
#  234,
#  345,
#  244,
#  2311,
#  23333,
#  33323,
#  3,
#  4,
#  4,
#  56,
#  32,
#  234,
#  4,
#  45,
#  3,
#  32,
#  344,
#  2333333,
#  98,
#  906,
#  566]

# %% [markdown]
# this list has duplicates, let's just return the first one.

# %%
new_arr = sorted(arr)
new_arr
# Out:
# [3,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  5,
#  24,
#  32,
#  32,
#  45,
#  56,
#  62,
#  98,
#  123,
#  234,
#  234,
#  244,
#  344,
#  345,
#  566,
#  906,
#  2311,
#  23333,
#  33323,
#  2333333]

# %%
## binary search, target is to found 56.

# new_arr

length = len(new_arr)
length


for i in range(new_arr, )
# Out:
#   Cell In[5], line 9
#     for i in range(new_arr, )
#                              ^
# SyntaxError: expected ':'

# %%
# lets write the algo first 

# how to find 56 okay,

# 1. Sort the list 
# 2. find the middle place and check the integer sitting in middle place with target 
# 3. if lower, then take first half
# 4. if higher, then take second half
# 5. repeat this process as much as possible


new_arr = sorted(arr)
middle_ = round(len(new_arr) / 2)
if new_arr[middle_] == target:
    print('yay')
elif new_arr[middle_] == target:

# middle_
# new_arr
# Out:
# 98

# %%
arr.sorted()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 arr.sorted()
#
# AttributeError: 'list' object has no attribute 'sorted'

# %%
print(arr)
# Out:
# None

# %% [markdown]
# Write a Python function binary_search(arr, target) that returns the index of target in the list using binary search. If the target is not found, return -1.
# What should binary_search(arr, target) return for the above input?

# %%
a
# Out:
# [3,
#  4,
#  5,
#  62,
#  24,
#  123,
#  234,
#  345,
#  244,
#  2311,
#  23333,
#  33323,
#  3,
#  4,
#  4,
#  56,
#  32,
#  234,
#  4,
#  45,
#  3,
#  32,
#  344,
#  2333333,
#  98,
#  906,
#  566]
